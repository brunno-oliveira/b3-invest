# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
os.chdir('..')

# %%
from package.models.linear_regressor import ModelLinearRegression

# %%
model_linear_reg = ModelLinearRegression()
model_linear_reg.set_model()
model_linear_reg.load_data()
# Out:
# [4924 ][2021-06-24 20:30:49][linear_regressor.py][set_model ][INFO ] Start
# [4924 ][2021-06-24 20:30:49][model_base.py][load_data ][INFO ] Start

# %%
model_linear_reg.fit_and_predict()
# Out:
# [4924 ][2021-06-24 20:30:52][linear_regressor.py][fit_and_predict][INFO ] Start
# [4924 ][2021-06-24 20:30:52][linear_regressor.py][fit       ][INFO ] Start
# [4924 ][2021-06-24 20:30:55][linear_regressor.py][predict   ][INFO ] Start
# (LinearRegression(),
#  array([ 19.34717274,  21.68467712,  15.68423748,  26.98707867,
#          34.15423203,  38.18238068,  38.43656731,  31.24718857,
#          15.64030933,  13.79024506,  14.07716179,  15.00762177,
#          35.83405495,  64.60235882,  13.60583019,  20.39067459,
#          19.08714294,  44.37282562,   9.17215633,  35.13441753,
#          34.23962307,  15.67708397,  16.80532932,  31.00709724,
#          14.03461838,  14.19248486,  19.41698742,  10.18362045,
#          25.68158722,  45.50270844,  50.26147461,  29.69090939,
#          32.08641052,  35.61243629,  35.18063927,  17.98972416,
#          16.39540863,  23.90806389,  22.37842751,  25.19925594,
#          19.56256294,  13.96657848,  15.55645084,  18.46090794,
# ...

# %%
model_linear_reg.plot_metrics()
# Out:
# [4924 ][2021-06-24 20:30:59][model_base.py][plot_metrics][INFO ] mape_score : 0.3378

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
fig, ax = plt.subplots(figsize=(30, 6))

sns.lineplot(
    x=list(model_linear_reg.y_data["ticker"]), 
    y=list(model_linear_reg.y_data["close"]))
ax.plot(model_linear_reg.predicted)
plt.xticks(rotation=90)

plt.show()
